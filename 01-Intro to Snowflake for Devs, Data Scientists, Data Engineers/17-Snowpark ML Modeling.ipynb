# %% [markdown]
# # Snowpark ML Modeling - Part I

# %%
%%sql -r dataframe_1
            SELECT 
                distinct PRIMARY_CITY
            FROM 
                TASTY_BYTES.ANALYTICS.ORDERS_V
            ORDER BY
                PRIMARY_CITY
